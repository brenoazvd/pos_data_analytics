# %% [markdown]
# Start Spark

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.master("local[*]").appName("SparkLocal").getOrCreate()
spark.range(5).show()
# Out:
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# |  3|
# |  4|
# +---+

# %% [markdown]
# Spark SQL - Consults and Selections

# %%
df = spark.sql('''select 'OK' as Status''')
df.show()
# Out:
# +------+
# |Status|
# +------+
# |    OK|
# +------+

# %% [markdown]
# Importing Data

# %%
df_cereal = spark.read.csv(
    r"C:\Users\00157NLUC-BrenoR\.cache\kagglehub\datasets\danthomasgeorge\cereal-nutrition\versions\2\Cereal.csv",
    sep=",", inferSchema=True, header=True
)
df_cereal.show(5)
# Out:
# +--------------------+---+----+--------+-------+---+------+-----+-----+------+------+--------+-----+----+---------+
# |                NAME|MFR|TYPE|CALORIES|PROTEIN|FAT|SODIUM|FIBER|CARBO|SUGARS|POTASS|VITAMINS|SHELF|CUPS|   RATING|
# +--------------------+---+----+--------+-------+---+------+-----+-----+------+------+--------+-----+----+---------+
# |           100% Bran|  N|   C|      70|      4|  1|   130| 10.0|  5.0|     6|   280|      25|    3|0.33|68.402973|
# |   100% Natural Bran|  Q|   C|     120|      3|  5|    15|  2.0|  8.0|     8|   135|       0|    3| 1.0|33.983679|
# |            All-Bran|  K|   C|      70|      4|  1|   260|  9.0|  7.0|     5|   320|      25|    3|0.33|59.425505|
# |All-Bran with Ext...|  K|   C|      50|      4|  0|   140| 14.0|  8.0|     0|   330|      25|    3| 0.5|93.704912|
# |      Almond Delight|  R|   C|     110|      2|  2|   200|  1.0| 14.0|     8|    -1|      25|    3|0.75|34.384843|
# +--------------------+---+----+--------+-------+---+------+-----+-----+------+------+--------+-----+----+---------+
# only showing top 5 rows

# %% [markdown]
# Manipulation Data with Spark SQL

# %%
df_cereal.createOrReplaceTempView("cereal")

# %%
cereal = spark.sql('''SELECT * FROM cereal WHERE type = 'C' ''')
cereal.show(5)
# Out:
# +--------------------+---+----+--------+-------+---+------+-----+-----+------+------+--------+-----+----+---------+
# |                NAME|MFR|TYPE|CALORIES|PROTEIN|FAT|SODIUM|FIBER|CARBO|SUGARS|POTASS|VITAMINS|SHELF|CUPS|   RATING|
# +--------------------+---+----+--------+-------+---+------+-----+-----+------+------+--------+-----+----+---------+
# |           100% Bran|  N|   C|      70|      4|  1|   130| 10.0|  5.0|     6|   280|      25|    3|0.33|68.402973|
# |   100% Natural Bran|  Q|   C|     120|      3|  5|    15|  2.0|  8.0|     8|   135|       0|    3| 1.0|33.983679|
# |            All-Bran|  K|   C|      70|      4|  1|   260|  9.0|  7.0|     5|   320|      25|    3|0.33|59.425505|
# |All-Bran with Ext...|  K|   C|      50|      4|  0|   140| 14.0|  8.0|     0|   330|      25|    3| 0.5|93.704912|
# |      Almond Delight|  R|   C|     110|      2|  2|   200|  1.0| 14.0|     8|    -1|      25|    3|0.75|34.384843|
# +--------------------+---+----+--------+-------+---+------+-----+-----+------+------+--------+-----+----+---------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import *

df_cereal.where(df_cereal['type'] == 'C').show()
# Out:
# +--------------------+---+----+--------+-------+---+------+-----+-----+------+------+--------+-----+----+---------+
# |                NAME|MFR|TYPE|CALORIES|PROTEIN|FAT|SODIUM|FIBER|CARBO|SUGARS|POTASS|VITAMINS|SHELF|CUPS|   RATING|
# +--------------------+---+----+--------+-------+---+------+-----+-----+------+------+--------+-----+----+---------+
# |           100% Bran|  N|   C|      70|      4|  1|   130| 10.0|  5.0|     6|   280|      25|    3|0.33|68.402973|
# |   100% Natural Bran|  Q|   C|     120|      3|  5|    15|  2.0|  8.0|     8|   135|       0|    3| 1.0|33.983679|
# |            All-Bran|  K|   C|      70|      4|  1|   260|  9.0|  7.0|     5|   320|      25|    3|0.33|59.425505|
# |All-Bran with Ext...|  K|   C|      50|      4|  0|   140| 14.0|  8.0|     0|   330|      25|    3| 0.5|93.704912|
# |      Almond Delight|  R|   C|     110|      2|  2|   200|  1.0| 14.0|     8|    -1|      25|    3|0.75|34.384843|
# |Apple Cinnamon Ch...|  G|   C|     110|      2|  2|   180|  1.5| 10.5|    10|    70|      25|    1|0.75|29.509541|
# |         Apple Jacks|  K|   C|     110|      2|  0|   125|  1.0| 11.0|    14|    30|      25|    2| 1.0|33.174094|
# |             Basic 4|  G|   C|     130|      3|  2|   210|  2.0| 18.0|     8|   100|      25|    3|0.75|37.038562|
# |           Bran Chex|  R|   C|      90|      2|  1|   200|  4.0| 15.0|     6|   125|      25|    1|0.67|49.120253|
# |         Bran Flakes|  P|   C|      90|      3|  0|   210|  5.0| 13.0|     5|   190|      25|    3|0.67|53.313813|
# |        Cap'n'Crunch|  Q|   C|     120|      1|  2|   220|  0.0| 12.0|    12|    35|      25|    2|0.75|18.042851|
# |            Cheerios|  G|   C|     110|      6|  2|   290|  2.0| 17.0|     1|   105|      25|    1|1.25|50.764999|
# |Cinnamon Toast Cr...|  G|   C|     120|      1|  3|   210|  0.0| 13.0|     9|    45|      25|    2|0.75|19.823573|
# |            Clusters|  G|   C|     110|      3|  2|   140|  2.0| 13.0|     7|   105|      25|    3| 0.5|40.400208|
# |         Cocoa Puffs|  G|   C|     110|      1|  1|   180|  0.0| 12.0|    13|    55|      25|    2| 1.0|22.736446|
# |           Corn Chex|  R|   C|     110|      2|  0|   280|  0.0| 22.0|     3|    25|      25|    1| 1.0|41.445019|
# |         Corn Flakes|  K|   C|     100|      2|  0|   290|  1.0| 21.0|     2|    35|      25|    1| 1.0|45.863324|
# |           Corn Pops|  K|   C|     110|      1|  0|    90|  1.0| 13.0|    12|    20|      25|    2| 1.0|35.782791|
# |       Count Chocula|  G|   C|     110|      1|  1|   180|  0.0| 12.0|    13|    65|      25|    2| 1.0|22.396513|
# |  Cracklin' Oat Bran|  K|   C|     110|      3|  3|   140|  4.0| 10.0|     7|   160|      25|    3| 0.5|40.448772|
# +--------------------+---+----+--------+-------+---+------+-----+-----+------+------+--------+-----+----+---------+
# only showing top 20 rows

# %%
df_cereal.where(df_cereal['mfr'] == 'G').show()
# Out:
# +--------------------+---+----+--------+-------+---+------+-----+-----+------+------+--------+-----+----+---------+
# |                NAME|MFR|TYPE|CALORIES|PROTEIN|FAT|SODIUM|FIBER|CARBO|SUGARS|POTASS|VITAMINS|SHELF|CUPS|   RATING|
# +--------------------+---+----+--------+-------+---+------+-----+-----+------+------+--------+-----+----+---------+
# |Apple Cinnamon Ch...|  G|   C|     110|      2|  2|   180|  1.5| 10.5|    10|    70|      25|    1|0.75|29.509541|
# |             Basic 4|  G|   C|     130|      3|  2|   210|  2.0| 18.0|     8|   100|      25|    3|0.75|37.038562|
# |            Cheerios|  G|   C|     110|      6|  2|   290|  2.0| 17.0|     1|   105|      25|    1|1.25|50.764999|
# |Cinnamon Toast Cr...|  G|   C|     120|      1|  3|   210|  0.0| 13.0|     9|    45|      25|    2|0.75|19.823573|
# |            Clusters|  G|   C|     110|      3|  2|   140|  2.0| 13.0|     7|   105|      25|    3| 0.5|40.400208|
# |         Cocoa Puffs|  G|   C|     110|      1|  1|   180|  0.0| 12.0|    13|    55|      25|    2| 1.0|22.736446|
# |       Count Chocula|  G|   C|     110|      1|  1|   180|  0.0| 12.0|    13|    65|      25|    2| 1.0|22.396513|
# |Crispy Wheat & Ra...|  G|   C|     100|      2|  1|   140|  2.0| 11.0|    10|   120|      25|    3|0.75|36.176196|
# |      Golden Grahams|  G|   C|     110|      1|  1|   280|  0.0| 15.0|     9|    45|      25|    2|0.75|23.804043|
# |  Honey Nut Cheerios|  G|   C|     110|      3|  1|   250|  1.5| 11.5|    10|    90|      25|    1|0.75|31.072217|
# |                 Kix|  G|   C|     110|      2|  1|   260|  0.0| 21.0|     3|    40|      25|    2| 1.5|39.241114|
# |        Lucky Charms|  G|   C|     110|      2|  1|   180|  0.0| 12.0|    12|    55|      25|    2| 1.0|26.734515|
# |Multi-Grain Cheerios|  G|   C|     100|      2|  1|   220|  2.0| 15.0|     6|    90|      25|    1| 1.0|40.105965|
# |Oatmeal Raisin Crisp|  G|   C|     130|      3|  2|   170|  1.5| 13.5|    10|   120|      25|    3| 0.5|30.450843|
# |     Raisin Nut Bran|  G|   C|     100|      3|  2|   140|  2.5| 10.5|     8|   140|      25|    3| 0.5|  39.7034|
# |   Total Corn Flakes|  G|   C|     110|      2|  1|   200|  0.0| 21.0|     3|    35|     100|    3| 1.0|38.839746|
# |   Total Raisin Bran|  G|   C|     140|      3|  1|   190|  4.0| 15.0|    14|   230|     100|    3| 1.0|28.592785|
# |   Total Whole Grain|  G|   C|     100|      3|  1|   200|  3.0| 16.0|     3|   110|     100|    3| 1.0|46.658844|
# |             Triples|  G|   C|     110|      2|  1|   250|  0.0| 21.0|     3|    60|      25|    3|0.75|39.106174|
# |                Trix|  G|   C|     110|      1|  1|   140|  0.0| 13.0|    12|    25|      25|    2| 1.0|27.753301|
# +--------------------+---+----+--------+-------+---+------+-----+-----+------+------+--------+-----+----+---------+
# only showing top 20 rows

# %%
df_cereal.where(df_cereal['mfr'] == 'G').count()
# Out:
# 22

# %%
cereal = spark.sql('''SELECT * FROM cereal WHERE mfr = 'G' ''')
cereal.count()
# Out:
# 22

# %%
cereal = spark.sql('''SELECT * FROM cereal WHERE mfr = 'G' ''')
cereal.show()
# Out:
# +--------------------+---+----+--------+-------+---+------+-----+-----+------+------+--------+-----+----+---------+
# |                NAME|MFR|TYPE|CALORIES|PROTEIN|FAT|SODIUM|FIBER|CARBO|SUGARS|POTASS|VITAMINS|SHELF|CUPS|   RATING|
# +--------------------+---+----+--------+-------+---+------+-----+-----+------+------+--------+-----+----+---------+
# |Apple Cinnamon Ch...|  G|   C|     110|      2|  2|   180|  1.5| 10.5|    10|    70|      25|    1|0.75|29.509541|
# |             Basic 4|  G|   C|     130|      3|  2|   210|  2.0| 18.0|     8|   100|      25|    3|0.75|37.038562|
# |            Cheerios|  G|   C|     110|      6|  2|   290|  2.0| 17.0|     1|   105|      25|    1|1.25|50.764999|
# |Cinnamon Toast Cr...|  G|   C|     120|      1|  3|   210|  0.0| 13.0|     9|    45|      25|    2|0.75|19.823573|
# |            Clusters|  G|   C|     110|      3|  2|   140|  2.0| 13.0|     7|   105|      25|    3| 0.5|40.400208|
# |         Cocoa Puffs|  G|   C|     110|      1|  1|   180|  0.0| 12.0|    13|    55|      25|    2| 1.0|22.736446|
# |       Count Chocula|  G|   C|     110|      1|  1|   180|  0.0| 12.0|    13|    65|      25|    2| 1.0|22.396513|
# |Crispy Wheat & Ra...|  G|   C|     100|      2|  1|   140|  2.0| 11.0|    10|   120|      25|    3|0.75|36.176196|
# |      Golden Grahams|  G|   C|     110|      1|  1|   280|  0.0| 15.0|     9|    45|      25|    2|0.75|23.804043|
# |  Honey Nut Cheerios|  G|   C|     110|      3|  1|   250|  1.5| 11.5|    10|    90|      25|    1|0.75|31.072217|
# |                 Kix|  G|   C|     110|      2|  1|   260|  0.0| 21.0|     3|    40|      25|    2| 1.5|39.241114|
# |        Lucky Charms|  G|   C|     110|      2|  1|   180|  0.0| 12.0|    12|    55|      25|    2| 1.0|26.734515|
# |Multi-Grain Cheerios|  G|   C|     100|      2|  1|   220|  2.0| 15.0|     6|    90|      25|    1| 1.0|40.105965|
# |Oatmeal Raisin Crisp|  G|   C|     130|      3|  2|   170|  1.5| 13.5|    10|   120|      25|    3| 0.5|30.450843|
# |     Raisin Nut Bran|  G|   C|     100|      3|  2|   140|  2.5| 10.5|     8|   140|      25|    3| 0.5|  39.7034|
# |   Total Corn Flakes|  G|   C|     110|      2|  1|   200|  0.0| 21.0|     3|    35|     100|    3| 1.0|38.839746|
# |   Total Raisin Bran|  G|   C|     140|      3|  1|   190|  4.0| 15.0|    14|   230|     100|    3| 1.0|28.592785|
# |   Total Whole Grain|  G|   C|     100|      3|  1|   200|  3.0| 16.0|     3|   110|     100|    3| 1.0|46.658844|
# |             Triples|  G|   C|     110|      2|  1|   250|  0.0| 21.0|     3|    60|      25|    3|0.75|39.106174|
# |                Trix|  G|   C|     110|      1|  1|   140|  0.0| 13.0|    12|    25|      25|    2| 1.0|27.753301|
# +--------------------+---+----+--------+-------+---+------+-----+-----+------+------+--------+-----+----+---------+
# only showing top 20 rows

# %%
cereal = spark.sql('''SELECT COUNT(*) AS total FROM cereal WHERE mfr = 'G' ''')
cereal.show()
# Out:
# +-----+
# |total|
# +-----+
# |   22|
# +-----+

# %% [markdown]
# Select DISTINTIC no SparkSQL

# %%
df_cereal.createOrReplaceTempView("cereal")

# %%
df_cereal.printSchema()
# Out:
# root
#  |-- NAME: string (nullable = true)
#  |-- MFR: string (nullable = true)
#  |-- TYPE: string (nullable = true)
#  |-- CALORIES: integer (nullable = true)
#  |-- PROTEIN: integer (nullable = true)
#  |-- FAT: integer (nullable = true)
#  |-- SODIUM: integer (nullable = true)
#  |-- FIBER: double (nullable = true)
#  |-- CARBO: double (nullable = true)
#  |-- SUGARS: integer (nullable = true)
#  |-- POTASS: integer (nullable = true)
#  |-- VITAMINS: integer (nullable = true)
#  |-- SHELF: integer (nullable = true)
#  |-- CUPS: double (nullable = true)
#  |-- RATING: double (nullable = true)

# %%
cereal = spark.sql('''SELECT DISTINCT type, mfr FROM  cereal ''')
cereal.show()
# Out:
# +----+----+
# |type| mfr|
# +----+----+
# |   C|   P|
# |   C|   Q|
# |   C|   N|
# |   H|   Q|
# |   C|   R|
# |   H|   N|
# |   C|   G|
# |   H|   A|
# |   C|   K|
# |NULL|NULL|
# +----+----+

# %% [markdown]
# WHERE no SparkSQL

# %%
cereal = spark.sql('''SELECT * FROM  cereal WHERE mfr = 'N' ''')
cereal.count()
# Out:
# 6

# %%
cereal = spark.sql('''SELECT * FROM  cereal WHERE calories = 100 ''')
cereal.count()
# Out:
# 17

# %%
cereal = spark.sql('''SELECT * FROM  cereal WHERE mfr = 'N'AND calories <= 100 ''')
cereal.count()
# Out:
# 6

# %% [markdown]
# Group By

# %%
cereal = spark.sql('''SELECT mfr, \
                   type, \
                   COUNT(*) AS total,
                   SUM(calories) AS total_calories
                FROM  cereal \
                 GROUP BY \
                   mfr, \
                   type ''')
cereal.show()
# Out:
# +----+----+-----+--------------+
# | mfr|type|total|total_calories|
# +----+----+-----+--------------+
# |   A|   H|    1|           100|
# |   P|   C|    8|           860|
# |NULL|NULL|    3|          NULL|
# |   K|   C|   23|          2500|
# |   G|   C|   22|          2450|
# |   Q|   C|    7|           660|
# |   R|   C|    6|           620|
# |   Q|   H|    1|           100|
# |   N|   H|    1|           100|
# |   N|   C|    5|           420|
# +----+----+-----+--------------+

# %% [markdown]
# CASE WHEN

# %%
cereal = spark.sql(''' SELECT mfr, type,
                (case 
                   when type = 'C' then 'A' 
                   when type = 'H' then 'B'
                   else 'C' 
                   end) AS type_new,
                   
                count(*) AS total,
                sum(calories) as total_calories
            FROM cereal
            GROUP BY
                mfr,
                type ''')
    
cereal.show()
# Out:
# +----+----+--------+-----+--------------+
# | mfr|type|type_new|total|total_calories|
# +----+----+--------+-----+--------------+
# |   A|   H|       B|    1|           100|
# |   P|   C|       A|    8|           860|
# |NULL|NULL|       C|    3|          NULL|
# |   K|   C|       A|   23|          2500|
# |   G|   C|       A|   22|          2450|
# |   Q|   C|       A|    7|           660|
# |   R|   C|       A|    6|           620|
# |   Q|   H|       B|    1|           100|
# |   N|   H|       B|    1|           100|
# |   N|   C|       A|    5|           420|
# +----+----+--------+-----+--------------+

# %% [markdown]
# Avanced Consults in SQL using PySpark

# %%
cereal = spark.sql('''
SELECT mfr,
       type,
       sum(calories) as sum_calories,
       min(calories) as min_calories,
       max(calories) as max_calories,
       avg(calories) as avg_calories,
       count(distinct name) as count_distinct_name,
       count(name) as count_names
FROM cereal
GROUP BY mfr, type
ORDER BY mfr, type
''')

cereal.show()
# Out:
# +----+----+------------+------------+------------+------------------+-------------------+-----------+
# | mfr|type|sum_calories|min_calories|max_calories|      avg_calories|count_distinct_name|count_names|
# +----+----+------------+------------+------------+------------------+-------------------+-----------+
# |NULL|NULL|        NULL|        NULL|        NULL|              NULL|                  2|          3|
# |   A|   H|         100|         100|         100|             100.0|                  1|          1|
# |   G|   C|        2450|         100|         140|111.36363636363636|                 22|         22|
# |   K|   C|        2500|          50|         160|108.69565217391305|                 23|         23|
# |   N|   C|         420|          70|          90|              84.0|                  5|          5|
# |   N|   H|         100|         100|         100|             100.0|                  1|          1|
# |   P|   C|         860|          90|         120|             107.5|                  8|          8|
# |   Q|   C|         660|          50|         120| 94.28571428571429|                  7|          7|
# |   Q|   H|         100|         100|         100|             100.0|                  1|          1|
# |   R|   C|         620|          90|         110|103.33333333333333|                  6|          6|
# +----+----+------------+------------+------------+------------------+-------------------+-----------+

# %%
cereal = spark.sql('''
SELECT mfr,
       type,
       sum(calories) as sum_calories,
       min(calories) as min_calories,
       max(calories) as max_calories,
       cast(avg(calories) as decimal(10,2)) as avg_calories,

        sum(vitamins) as sum_vitamins,
       min(vitamins) as min_vitamins,
       max(vitamins) as max_vitamins,
       cast(avg(vitamins) as decimal(10,2)) as avg_vitamins,

       sum(carbo) as sum_carbo,
       min(carbo) as min_carbo,
       max(carbo) as max_carbo,
       cast(avg(carbo) as decimal(10,2)) as avg_carbo,

       count(distinct name) as count_distinct_name,
       count(name) as count_names
FROM cereal
GROUP BY mfr, type
ORDER BY mfr, type
''')

cereal.show()
# Out:
# +----+----+------------+------------+------------+------------+------------+------------+------------+------------+---------+---------+---------+---------+-------------------+-----------+
# | mfr|type|sum_calories|min_calories|max_calories|avg_calories|sum_vitamins|min_vitamins|max_vitamins|avg_vitamins|sum_carbo|min_carbo|max_carbo|avg_carbo|count_distinct_name|count_names|
# +----+----+------------+------------+------------+------------+------------+------------+------------+------------+---------+---------+---------+---------+-------------------+-----------+
# |NULL|NULL|        NULL|        NULL|        NULL|        NULL|        NULL|        NULL|        NULL|        NULL|     NULL|     NULL|     NULL|     NULL|                  2|          3|
# |   A|   H|         100|         100|         100|      100.00|          25|          25|          25|       25.00|     16.0|     16.0|     16.0|    16.00|                  1|          1|
# |   G|   C|        2450|         100|         140|      111.36|         775|          25|         100|       35.23|    324.0|     10.5|     21.0|    14.73|                 22|         22|
# |   K|   C|        2500|          50|         160|      108.70|         800|          25|         100|       34.78|    348.0|      7.0|     22.0|    15.13|                 23|         23|
# |   N|   C|         420|          70|          90|       84.00|          50|           0|          25|       10.00|     75.0|      5.0|     20.0|    15.00|                  5|          5|
# |   N|   H|         100|         100|         100|      100.00|           0|           0|           0|        0.00|     21.0|     21.0|     21.0|    21.00|                  1|          1|
# |   P|   C|         860|          90|         120|      107.50|         200|          25|          25|       25.00|    107.0|     11.0|     17.0|    13.38|                  8|          8|
# |   Q|   C|         660|          50|         120|       94.29|         100|           0|          25|       14.29|     81.0|      8.0|     14.0|    11.57|                  7|          7|
# |   Q|   H|         100|         100|         100|      100.00|           0|           0|           0|        0.00|     -1.0|     -1.0|     -1.0|    -1.00|                  1|          1|
# |   R|   C|         620|          90|         110|      103.33|         150|          25|          25|       25.00|    109.0|     14.0|     23.0|    18.17|                  6|          6|
# +----+----+------------+------------+------------+------------+------------+------------+------------+------------+---------+---------+---------+---------+-------------------+-----------+

# %%
cereal = spark.sql('''
SELECT mfr,
       type,
        (case
            when
        end)
        sum(calories) as sum_calories,
       min(calories) as min_calories,
       max(calories) as max_calories,
       cast(avg(calories) as decimal(10,2)) as avg_calories,

        sum(vitamins) as sum_vitamins,
       min(vitamins) as min_vitamins,
       max(vitamins) as max_vitamins,
       cast(avg(vitamins) as decimal(10,2)) as avg_vitamins,

       sum(carbo) as sum_carbo,
       min(carbo) as min_carbo,
       max(carbo) as max_carbo,
       cast(avg(carbo) as decimal(10,2)) as avg_carbo,

       count(distinct name) as count_distinct_name,
       count(name) as count_names
FROM cereal
GROUP BY mfr, type
ORDER BY mfr, type
''')

cereal.show()
